# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivamkumar-eng/AWS_python/blob/main/day1ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("learning ml during aws ml engineering tranning")
# Out:
# learning ml during aws ml engineering tranning

# %%
# variable
num = 10
print(num)
print(id(num))
print(type(num))

num1 = 10
print(num1)
print(id(num1))
# Out:
# 10
# 11645640
# <class 'int'>
# 10
# 11645640

# %%
# string
name = "chandan"

print(name)
print(id(name))
print(type(name))
# Out:
# chandan
# 134347530121408
# <class 'str'>

# %%
# boolean
is_chandanactive = True

print(is_chandanactive)
print(id(is_chandanactive))
print(type(is_chandanactive))
# Out:
# True
# 10549600
# <class 'bool'>
