# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivamkumar-eng/AWS_MACHINE_LEARNING/blob/main/day1ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("learning ml during aws ml engineering tranning")
# Out:
# learning ml during aws ml engineering tranning
