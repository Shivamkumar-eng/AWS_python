# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivamkumar-eng/AWS_python/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# arithmatic operator

# %%
a=10
b=20
print(a+b)
# Out:
# 30

# %%
a=10
b=20
print(a-b)
# Out:
# -10

# %%
a=10
b=20
print(a*b)
# Out:
# 200

# %%
a=2
b=23
print(b/a)
# Out:
# 11.5

# %%
a=13
b=2
print(a//b)
# Out:
# 6

# %%
a=15
b=2
print(a%b)
# Out:
# 1

# %% [markdown]
# assignment operators

# %%
x = 10

x += 5
print(x)

x -= 3
print(x)

x *= 2
print(x)

x //= 5
print(x)
# Out:
# 15
# 12
# 24
# 4

# %% [markdown]
# relational operators

# %%
a = 10
b = 20

print(a == b)
print(a != b)
print(a > b)
print(a < b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
a = 10
b = 20

print(a > 5 and b > 15)
print(a > 15 or b > 15)
print(not(a > 5))
# Out:
# True
# True
# False
